# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import yfinance as yf
from scipy.stats import norm
import requests
from io import StringIO
import seaborn as sns; sns.set()
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (10,6)
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
mean = 0
std_dev = 1
x = np.arange(-5, 5, 0.01)
y = norm.pdf(x, mean, std_dev)
pdf = plt.plot(x, y)
min_ylim, max_ylim = plt.ylim()
plt.text(np.percentile(x, 5), max_ylim * 0.9, '95%:${:.4f}'
         .format(np.percentile(x, 5)))
plt.axvline(np.percentile(x, 5), color='r', linestyle='dashed',
            linewidth=4)
plt.title('Value at Risk Illustration')
plt.show()

# %%
def getDailyData(symbol):
        parameters = {'function': 'TIME_SERIES_DAILY_ADJUSTED', 
                      'symbol': symbol,
                       'outputsize':'full',
                       'datatype': 'csv', 
                       'apikey': 'insert your api key here'}

        response = requests.get('https://www.alphavantage.co/query',
                                params=parameters)

        csvText = StringIO(response.text)
        data = pd.read_csv(csvText, index_col='timestamp')
        return data

# %%
symbols = ["IBM", "MSFT", "INTC"]
stock3 = []
for symbol in symbols:
    stock3.append(getDailyData(symbol)[::-1]['close']
                  ['2020-01-01': '2020-12-31'])
stocks = pd.DataFrame(stock3).T
stocks.columns = symbols

# %%
stocks.head()
# Out:
#                IBM    MSFT   INTC
# timestamp
# 2020-01-02  135.42  160.62  60.84
# 2020-01-03  134.34  158.62  60.10
# 2020-01-06  134.10  159.03  59.93
# 2020-01-07  134.19  157.58  58.93
# 2020-01-08  135.31  160.09  58.97

# %% [markdown]
# ## Variance-Covariance Method

# %%
stocks_returns = (np.log(stocks) - np.log(stocks.shift(1))).dropna()
stocks_returns
# Out:
#                  IBM      MSFT      INTC
# timestamp
# 2020-01-03 -0.008007 -0.012530 -0.012238
# 2020-01-06 -0.001788  0.002581 -0.002833
# 2020-01-07  0.000671 -0.009160 -0.016827
# 2020-01-08  0.008312  0.015803  0.000679
# 2020-01-09  0.010513  0.012416  0.005580
# ...              ...       ...       ...
# 2020-12-24  0.006356  0.007797  0.010679
# 2020-12-28  0.001042  0.009873  0.000000
# 2020-12-29 -0.008205 -0.003607  0.048112
# 2020-12-30  0.004352 -0.011081 -0.013043
# 2020-12-31  0.012309  0.003333  0.021711
#
# [252 rows x 3 columns]

# %%
stocks_returns_mean = stocks_returns.mean()
weights  = np.random.random(len(stocks_returns.columns))
weights /= np.sum(weights)
cov_var = stocks_returns.cov()
port_std = np.sqrt(weights.T.dot(cov_var).dot(weights))

# %%
initial_investment = 1e6
conf_level = 0.95

# %%
def VaR_parametric(initial_investment, conf_level):
    alpha = norm.ppf(1 - conf_level, stocks_returns_mean, port_std)
    for i, j in zip(stocks.columns, range(len(stocks.columns))):
        VaR_param = (initial_investment - initial_investment * 
                     (1 + alpha))[j]
        print("Parametric VaR result for {} is {} "
              .format(i, VaR_param))
    VaR_param = (initial_investment - initial_investment * (1 + alpha))
    print('--' * 25)
    return VaR_param

# %%
VaR_param = VaR_parametric(initial_investment, conf_level)
VaR_param
# Out:
# Parametric VaR result for IBM is 42536.85725276801
# Parametric VaR result for MSFT is 40955.197937324876
# Parametric VaR result for INTC is 43039.94840235438
# --------------------------------------------------
# array([42536.85725277, 40955.19793732, 43039.94840235])

# %%
var_horizon = []
time_horizon = 30
for j in range(len(stocks_returns.columns)):
    for i in range(1, time_horizon + 1):
        var_horizon.append(VaR_param[j] * np.sqrt(i))
plt.plot(var_horizon[:time_horizon], "o",
         c='blue', marker='*', label='IBM')
plt.plot(var_horizon[time_horizon:time_horizon + 30], "o",
         c='green', marker='o', label='MSFT')
plt.plot(var_horizon[time_horizon + 30:time_horizon + 60], "o",
         c='red', marker='v', label='INTC')
plt.xlabel("Days")
plt.ylabel("USD")
plt.title("VaR over 30-day period")
plt.legend()
plt.show()

# %% [markdown]
# ## Historical Simulation VaR

# %%
def VaR_historical(initial_investment, conf_level):
    Hist_percentile95 = []
    for i, j in zip(stocks_returns.columns,
                    range(len(stocks_returns.columns))):
        Hist_percentile95.append(np.percentile(stocks_returns.loc[:, i],
                                               5))
        print("Based on historical values 95% of {}'s return is {:.4f}"
              .format(i, Hist_percentile95[j]))
        VaR_historical = (initial_investment - initial_investment *
                          (1 + Hist_percentile95[j]))
        print("Historical VaR result for {} is {:.2f} "
              .format(i, VaR_historical))
        print('--' * 35)

# %%
VaR_historical(initial_investment,conf_level)
# Out:
# Based on historical values 95% of IBM's return is -0.0371
# Historical VaR result for IBM is 37081.53
# ----------------------------------------------------------------------
# Based on historical values 95% of MSFT's return is -0.0426
# Historical VaR result for MSFT is 42583.68
# ----------------------------------------------------------------------
# Based on historical values 95% of INTC's return is -0.0425
# Historical VaR result for INTC is 42485.39
# ----------------------------------------------------------------------

# %% [markdown]
# ## Monte Carlo VaR

# %%
x = np.random.uniform(-1, 1, 100) 
y = np.random.uniform(-1, 1, 100)

# %%
sample = 100    
def pi_calc(x, y):
    point_inside_circle = 0
    for i in range(sample):
        if np.sqrt(x[i] ** 2 + y[i] ** 2) <= 1:
            point_inside_circle += 1 
    print('pi value is {}'.format(4 * point_inside_circle/sample))

# %%
pi_calc(x,y)
# Out:
# pi value is 3.0

# %%
x = np.random.uniform(-1, 1, 1000000)
y = np.random.uniform(-1, 1, 1000000)

# %%
sample = 1000000   

def pi_calc(x, y):
    point_inside_circle = 0
    for i in range(sample):
        if np.sqrt(x[i] ** 2 + y[i] ** 2) < 1:
            point_inside_circle += 1 
    print('pi value is {:.2f}'.format(4 * point_inside_circle/sample))

# %%
pi_calc(x,y)
# Out:
# pi value is 3.14

# %%
sim_data = pd.DataFrame([])
num_reps = 1000
n = 100
for i in range(len(stocks.columns)):
    mean = np.random.randn(n).mean()
    std = np.random.randn(n).std()
    temp = pd.DataFrame(np.random.normal(mean, std, num_reps))
    sim_data = pd.concat([sim_data, temp], axis=1)
sim_data.columns = ['Simulation 1', 'Simulation 2', 'Simulation 3']

# %%
sim_data
# Out:
#      Simulation 1  Simulation 2  Simulation 3
# 0       -0.780864     -0.590310      0.668967
# 1        0.669149     -0.202687      0.407628
# 2       -0.135419      0.171569      0.175225
# 3        0.204478      1.444232      0.884139
# 4       -0.419124     -0.451910     -1.038984
# ..            ...           ...           ...
# 995      0.057260      0.321951     -1.101677
# 996      0.907418     -0.074612      1.098919
# 997      0.448032      1.071440     -0.533628
# 998     -0.016345     -0.287462      1.642664
# 999      0.514297      0.336212      0.656267
#
# [1000 rows x 3 columns]

# %%
def MC_VaR(initial_investment, conf_level):
    MC_percentile95 = []
    for i, j in zip(sim_data.columns, range(len(sim_data.columns))):
        MC_percentile95.append(np.percentile(sim_data.loc[:, i], 5))
        print("Based on simulation 95% of {}'s return is {:.4f}"
              .format(i, MC_percentile95[j]))
        VaR_MC = (initial_investment - initial_investment * 
                  (1 + MC_percentile95[j]))
        print("Simulation VaR result for {} is {:.2f} "
              .format(i, VaR_MC))
        print('--' * 35)

# %%
MC_VaR(initial_investment, conf_level)
# Out:
# Based on simulation 95% of Simulation 1's return is -1.6439
# Simulation VaR result for Simulation 1 is 1643945.85
# ----------------------------------------------------------------------
# Based on simulation 95% of Simulation 2's return is -1.5627
# Simulation VaR result for Simulation 2 is 1562654.99
# ----------------------------------------------------------------------
# Based on simulation 95% of Simulation 3's return is -1.7157
# Simulation VaR result for Simulation 3 is 1715695.76
# ----------------------------------------------------------------------

# %% [markdown]
# ## The Marcenko-Pastur Theory

# %%
def mp_pdf(sigma2, q, obs):
    lambda_plus = sigma2 * (1 + q ** 0.5) ** 2
    lambda_minus = sigma2 * (1 - q ** 0.5) ** 2
    l = np.linspace(lambda_minus, lambda_plus, obs)
    pdf_mp = 1 / (2 * np.pi * sigma2 * q * l) \
             * np.sqrt((lambda_plus  - l) 
             *  (l - lambda_minus))
    pdf_mp = pd.Series(pdf_mp, index=l)
    return pdf_mp

# %%
from sklearn.neighbors import KernelDensity

def kde_fit(bandwidth,obs,x=None):
    kde = KernelDensity(bandwidth=bandwidth, kernel='gaussian')
    if len(obs.shape) == 1:
        kde_fit=kde.fit(np.array(obs).reshape(-1, 1))
    if x is None:
        x=np.unique(obs).reshape(-1, 1)
    if len(x.shape) == 1:
        x = x.reshape(-1, 1)
    logprob = kde_fit.score_samples(x)
    pdf_kde = pd.Series(np.exp(logprob), index=x.flatten())
    return pdf_kde

# %%
corr_mat = np.random.normal(size=(10000, 1000))
corr_coef = np.corrcoef(corr_mat, rowvar=0)
sigma2 = 1
obs = corr_mat.shape[0]
q = corr_mat.shape[0] / corr_mat.shape[1]

def plotting(corr_coef, q):
    ev, _ = np.linalg.eigh(corr_coef)
    idx = ev.argsort()[::-1]
    eigen_val = np.diagflat(ev[idx])
    pdf_mp = mp_pdf(1., q=corr_mat.shape[1] / corr_mat.shape[0],
                    obs=1000)
    kde_pdf = kde_fit(0.01, np.diag(eigen_val))
    ax = pdf_mp.plot(title="Marchenko-Pastur Theorem",
                     label="M-P", style='r--')
    kde_pdf.plot(label="Empirical Density", style='o-', alpha=0.3)
    ax.set(xlabel="Eigenvalue", ylabel="Frequency")
    ax.legend(loc="upper right")
    plt.show()
    return plt

# %%
plotting(corr_coef, q);

# %%
# !pip install PyPortfolioOpt
# Out:
# Collecting PyPortfolioOpt
#   Downloading pyportfolioopt-1.5.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 1.9 MB/s eta 0:00:00
# Collecting numpy<2.0.0,>=1.22.4
#   Downloading numpy-1.24.1-cp310-cp310-macosx_11_0_arm64.whl (13.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 41.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas>=0.19 in /Users/rz/mambaforge/lib/python3.10/site-packages (from PyPortfolioOpt) (1.5.2)
# Collecting cvxpy<2.0.0,>=1.1.10
#   Downloading cvxpy-1.3.0-cp310-cp310-macosx_10_9_universal2.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.9 MB/s eta 0:00:0000:01
# Requirement already satisfied: scipy<2.0,>=1.3 in /Users/rz/mambaforge/lib/python3.10/site-packages (from PyPortfolioOpt) (1.8.0)
# Collecting setuptools<=64.0.2
#   Downloading setuptools-64.0.2-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.0 MB/s eta 0:00:0000:01
# Collecting scs>=1.1.6
#   Downloading scs-3.2.2.tar.gz (663 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 kB 16.6 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ecos>=2
#   Downloading ecos-2.0.12.tar.gz (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.4/142.4 kB 6.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting osqp>=0.4.1
#   Downloading osqp-0.6.2.post8.tar.gz (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 9.3 MB/s eta 0:00:00
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [178 lines of output]
#       Collecting oldest-supported-numpy
#         Using cached oldest_supported_numpy-2022.11.19-py3-none-any.whl (4.9 kB)
#       Collecting setuptools>=40.8.0
#         Using cached setuptools-65.6.3-py3-none-any.whl (1.2 MB)
#       Collecting wheel
#         Using cached wheel-0.38.4-py3-none-any.whl (36 kB)
#       Collecting setuptools_scm>=6.2
#         Downloading setuptools_scm-7.1.0-py3-none-any.whl (43 kB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 1.3 MB/s eta 0:00:00
#       Collecting qdldl
#         Downloading qdldl-0.1.5.post2.tar.gz (69 kB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 2.6 MB/s eta 0:00:00
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting numpy==1.21.6
#         Using cached numpy-1.21.6-cp310-cp310-macosx_11_0_arm64.whl (12.4 MB)
#       Collecting typing-extensions
#         Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
#       Collecting tomli>=1.0.0
#         Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
#       Collecting packaging>=20.0
#         Downloading packaging-22.0-py3-none-any.whl (42 kB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.6 MB/s eta 0:00:00
#       Collecting scipy>=0.13.2
#         Downloading scipy-1.10.0-cp310-cp310-macosx_12_0_arm64.whl (28.8 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 38.0 MB/s eta 0:00:00
#       Building wheels for collected packages: qdldl
#         Building wheel for qdldl (setup.py): started
#         Building wheel for qdldl (setup.py): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × python setup.py bdist_wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [58 lines of output]
#             running bdist_wheel
#             running build
#             running build_ext
#             Traceback (most recent call last):
#               File "/private/var/folders/83/wyld6rbs37jg06dnrv50h1sh0000gn/T/pip-install-i78n_b4g/qdldl_3733850e5ddd436fad68a93da16bc6b7/setup.py", line 78, in build_extensions
#                 check_output(['cmake', '--version'])
#               File "/Users/rz/mambaforge/lib/python3.10/subprocess.py", line 420, in check_output
#                 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#               File "/Users/rz/mambaforge/lib/python3.10/subprocess.py", line 501, in run
#                 with Popen(*popenargs, **kwargs) as process:
#               File "/Users/rz/mambaforge/lib/python3.10/subprocess.py", line 969, in __init__
#                 self._execute_child(args, executable, preexec_fn, close_fds,
#               File "/Users/rz/mambaforge/lib/python3.10/subprocess.py", line 1845, in _execute_child
#                 raise child_exception_type(errno_num, err_msg, err_filename)
#             FileNotFoundError: [Errno 2] No such file or directory: 'cmake'
#
#             During handling of the above exception, another exception occurred:
#
#             Traceback (most recent call last):
#               File "<string>", line 2, in <module>
#               File "<pip-setuptools-caller>", line 34, in <module>
#               File "/private/var/folders/83/wyld6rbs37jg06dnrv50h1sh0000gn/T/pip-install-i78n_b4g/qdldl_3733850e5ddd436fad68a93da16bc6b7/setup.py", line 110, in <module>
#                 setup(name='qdldl',
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/__init__.py", line 87, in setup
#                 return distutils.core.setup(**attrs)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#                 return run_commands(dist)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#                 dist.run_commands()
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 973, in run_commands
#                 self.run_command(cmd)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/dist.py", line 1217, in run_command
#                 super().run_command(command)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 992, in run_command
#                 cmd_obj.run()
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/wheel/bdist_wheel.py", line 299, in run
#                 self.run_command('build')
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 319, in run_command
#                 self.distribution.run_command(command)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/dist.py", line 1217, in run_command
#                 super().run_command(command)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 992, in run_command
#                 cmd_obj.run()
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/command/build.py", line 132, in run
#                 self.run_command(cmd_name)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 319, in run_command
#                 self.distribution.run_command(command)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/dist.py", line 1217, in run_command
#                 super().run_command(command)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 992, in run_command
#                 cmd_obj.run()
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/command/build_ext.py", line 84, in run
#                 _build_ext.run(self)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 346, in run
#                 self.build_extensions()
#               File "/private/var/folders/83/wyld6rbs37jg06dnrv50h1sh0000gn/T/pip-install-i78n_b4g/qdldl_3733850e5ddd436fad68a93da16bc6b7/setup.py", line 80, in build_extensions
#                 raise RuntimeError("CMake must be installed to build qdldl")
#             RuntimeError: CMake must be installed to build qdldl
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed building wheel for qdldl
#         Running setup.py clean for qdldl
#       Failed to build qdldl
#       Installing collected packages: wheel, typing-extensions, tomli, setuptools, packaging, numpy, setuptools_scm, scipy, oldest-supported-numpy, qdldl
#         Running setup.py install for qdldl: started
#         Running setup.py install for qdldl: finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Running setup.py install for qdldl did not run successfully.
#         │ exit code: 1
#         ╰─> [62 lines of output]
#             running install
#             /Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#               warnings.warn(
#             running build
#             running build_ext
#             Traceback (most recent call last):
#               File "/private/var/folders/83/wyld6rbs37jg06dnrv50h1sh0000gn/T/pip-install-i78n_b4g/qdldl_3733850e5ddd436fad68a93da16bc6b7/setup.py", line 78, in build_extensions
#                 check_output(['cmake', '--version'])
#               File "/Users/rz/mambaforge/lib/python3.10/subprocess.py", line 420, in check_output
#                 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#               File "/Users/rz/mambaforge/lib/python3.10/subprocess.py", line 501, in run
#                 with Popen(*popenargs, **kwargs) as process:
#               File "/Users/rz/mambaforge/lib/python3.10/subprocess.py", line 969, in __init__
#                 self._execute_child(args, executable, preexec_fn, close_fds,
#               File "/Users/rz/mambaforge/lib/python3.10/subprocess.py", line 1845, in _execute_child
#                 raise child_exception_type(errno_num, err_msg, err_filename)
#             FileNotFoundError: [Errno 2] No such file or directory: 'cmake'
#
#             During handling of the above exception, another exception occurred:
#
#             Traceback (most recent call last):
#               File "<string>", line 2, in <module>
#               File "<pip-setuptools-caller>", line 34, in <module>
#               File "/private/var/folders/83/wyld6rbs37jg06dnrv50h1sh0000gn/T/pip-install-i78n_b4g/qdldl_3733850e5ddd436fad68a93da16bc6b7/setup.py", line 110, in <module>
#                 setup(name='qdldl',
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/__init__.py", line 87, in setup
#                 return distutils.core.setup(**attrs)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#                 return run_commands(dist)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#                 dist.run_commands()
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 973, in run_commands
#                 self.run_command(cmd)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/dist.py", line 1217, in run_command
#                 super().run_command(command)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 992, in run_command
#                 cmd_obj.run()
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/command/install.py", line 68, in run
#                 return orig.install.run(self)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/command/install.py", line 698, in run
#                 self.run_command('build')
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 319, in run_command
#                 self.distribution.run_command(command)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/dist.py", line 1217, in run_command
#                 super().run_command(command)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 992, in run_command
#                 cmd_obj.run()
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/command/build.py", line 132, in run
#                 self.run_command(cmd_name)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 319, in run_command
#                 self.distribution.run_command(command)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/dist.py", line 1217, in run_command
#                 super().run_command(command)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 992, in run_command
#                 cmd_obj.run()
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/command/build_ext.py", line 84, in run
#                 _build_ext.run(self)
#               File "/Users/rz/mambaforge/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 346, in run
#                 self.build_extensions()
#               File "/private/var/folders/83/wyld6rbs37jg06dnrv50h1sh0000gn/T/pip-install-i78n_b4g/qdldl_3733850e5ddd436fad68a93da16bc6b7/setup.py", line 80, in build_extensions
#                 raise RuntimeError("CMake must be installed to build qdldl")
#             RuntimeError: CMake must be installed to build qdldl
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: legacy-install-failure
#
#       × Encountered error while trying to install package.
#       ╰─> qdldl
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for output from the failure.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %% [markdown]
# ## Denoising

# %%
import portfoliolab as pl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [69], in <cell line: 1>()
# ----> 1 import portfoliolab as pl
#
# ModuleNotFoundError: No module named 'portfoliolab'

# %%
#pip install portfoliolab
# Out:
#   Input In [34]
#     pip  install PyPortfolioOpt
#          ^
# SyntaxError: invalid syntax

# %%
risk_estimators = pl.estimators.RiskEstimators()

# %%
stock_prices = stocks.copy()

# %%
cov_matrix = stocks_returns.cov()
cov_matrix

# %%
tn_relation = stock_prices.shape[0] / stock_prices.shape[1]
kde_bwidth = 0.25
cov_matrix_denoised = risk_estimators.denoise_covariance(cov_matrix,
                                                         tn_relation,
                                                         kde_bwidth)
cov_matrix_denoised = pd.DataFrame(cov_matrix_denoised,
                                   index=cov_matrix.index,
                                   columns=cov_matrix.columns)
cov_matrix_denoised
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 tn_relation = stock_prices.shape[0] / stock_prices.shape[1]
#       2 kde_bwidth = 0.25
#       3 cov_matrix_denoised = risk_estimators.denoise_covariance(cov_matrix,
#       4                                                          tn_relation,
#       5                                                          kde_bwidth)
#
# NameError: name 'stock_prices' is not defined

# %%
def VaR_parametric_denoised(initial_investment, conf_level):
    port_std = np.sqrt(weights.T.dot(cov_matrix_denoised)
                       .dot(weights))
    alpha = norm.ppf(1 - conf_level, stocks_returns_mean, port_std)
    for i, j in zip(stocks.columns,range(len(stocks.columns))):
        print("Parametric VaR result for {} is {} ".format(i,VaR_param))
    VaR_params = (initial_investment - initial_investment * (1 + alpha))
    print('--' * 25)
    return VaR_params

# %%
VaR_parametric_denoised(initial_investment, conf_level)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 VaR_parametric_denoised(initial_investment, conf_level)
#
# NameError: name 'VaR_parametric_denoised' is not defined

# %%
symbols = ["IBM", "MSFT", "INTC"]
stock3 = []
for symbol in symbols:
    stock3.append(getDailyData(symbol)[::-1]['close']
                  ['2007-04-01': '2009-02-01'])
stocks_crisis = pd.DataFrame(stock3).T
stocks_crisis.columns = symbols
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 3>()
#       2 stock3 = []
#       3 for symbol in symbols:
# ----> 4     stock3.append(getDailyData(symbol)[::-1]['close']
#       5                   ['2007-04-01': '2009-02-01'])
#       6 stocks_crisis = pd.DataFrame(stock3).T
#       7 stocks_crisis.columns = symbols
#
# Input In [3], in getDailyData(symbol)
#       8 response = requests.get('https://www.alphavantage.co/query',
#       9                         params=parameters)
#      11 csvText = StringIO(response.text)
# ---> 12 data = pd.read_csv(csvText, index_col='timestamp')
#      13 return data
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1250, in TextFileReader.read(self, nrows)
#    1248 nrows = validate_integer("nrows", nrows)
#    1249 try:
# -> 1250     index, columns, col_dict = self._engine.read(nrows)
#    1251 except Exception:
#    1252     self.close()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:311, in CParserWrapper.read(self, nrows)
#     308     data = {k: v for k, (i, v) in zip(names, data_tups)}
#     310     names, date_data = self._do_date_conversions(names, data)
# --> 311     index, names = self._make_index(date_data, alldata, names)
#     313 # maybe create a mi on the columns
#     314 conv_names = self._maybe_make_multi_index_columns(names, self.col_names)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py:389, in ParserBase._make_index(self, data, alldata, columns, indexnamerow)
#     386     index = None
#     388 elif not self._has_complex_date_col:
# --> 389     index = self._get_simple_index(alldata, columns)
#     390     index = self._agg_index(index)
#     391 elif self._has_complex_date_col:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py:421, in ParserBase._get_simple_index(self, data, columns)
#     419 index = []
#     420 for idx in self.index_col:
# --> 421     i = ix(idx)
#     422     to_remove.append(i)
#     423     index.append(data[i])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py:416, in ParserBase._get_simple_index.<locals>.ix(col)
#     414 if not isinstance(col, str):
#     415     return col
# --> 416 raise ValueError(f"Index {col} invalid")
#
# ValueError: Index timestamp invalid

# %%
stocks_crisis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 stocks_crisis
#
# NameError: name 'stocks_crisis' is not defined

# %%
stock_prices = stocks_crisis.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 stock_prices = stocks_crisis.copy()
#
# NameError: name 'stocks_crisis' is not defined

# %%
stocks_returns = (np.log(stocks) - np.log(stocks.shift(1))).dropna()

# %%
cov_matrix = stocks_returns.cov()

# %%
VaR_parametric(initial_investment, conf_level)

# %%
VaR_parametric_denoised(initial_investment, conf_level)

# %% [markdown]
# ## Checking Sub-additivity

# %%
asset1 = [-0.5, 0, 0.1, 0.4]
VaR1 = np.percentile(asset1, 90)
print('VaR for the Asset 1 is {:.4f}'.format(VaR1))
asset2 = [0, -0.5, 0.01, 0.4]
VaR2 = np.percentile(asset2, 90)
print('VaR for the Asset 2 is {:.4f}'.format(VaR2))
VaR_all = np.percentile(asset1 + asset2, 90)
print('VaR for the portfolio is {:.4f}'.format(VaR_all))
# Out:
# VaR for the Asset 1 is 0.3100
# VaR for the Asset 2 is 0.2830
# VaR for the portfolio is 0.4000

# %%
asset1 = [-0.5, 0, 0.05, 0.03]
VaR1 = np.percentile(asset1, 90)
print('VaR for the Asset 1 is {:.4f}'.format(VaR1))
asset2 = [0, -0.5, 0.02, 0.8]
VaR2 = np.percentile(asset2,90)
print('VaR for the Asset 2 is {:.4f}'.format(VaR2))
VaR_all = np.percentile(asset1 + asset2 , 90)
print('VaR for the portfolio is {:.4f}'.format(VaR_all))
# Out:
# VaR for the Asset 1 is 0.0440
# VaR for the Asset 2 is 0.5660
# VaR for the portfolio is 0.2750

# %% [markdown]
# ## Expected Shortfall

# %%
def ES_parametric(initial_investment , conf_level):
    alpha = - norm.ppf(1 - conf_level,stocks_returns_mean,port_std)
    for i, j in zip(stocks.columns, range(len(stocks.columns))):
        VaR_param = (initial_investment * alpha)[j]
        ES_param = (1 / (1 - conf_level)) \
                   * initial_investment \
                   * norm.expect(lambda x: x,
                                 lb = norm.ppf(conf_level,
                                               stocks_returns_mean[j],
                                               port_std),
                                 loc = stocks_returns_mean[j],
                                 scale = port_std)
        print(f"Parametric ES result for {i} is {ES_param}")

# %%
ES_parametric(initial_investment, conf_level)
# Out:
# Parametric ES result for IBM is 51865.3982359592
# Parametric ES result for MSFT is 53447.05755140234
# Parametric ES result for INTC is 51362.30708637284

# %%
def ES_historical(initial_investment, conf_level):
    for i, j in zip(stocks_returns.columns, 
                    range(len(stocks_returns.columns))):
        ES_hist_percentile95 = np.percentile(stocks_returns.loc[:, i],
                                             5)
        ES_historical = stocks_returns[str(i)][stocks_returns[str(i)] <=
                                               ES_hist_percentile95]\
                                               .mean()
        print("Historical ES result for {} is {:.4f} "
              .format(i, initial_investment * ES_historical))

# %%
ES_historical(initial_investment, conf_level)
# Out:
# Historical ES result for IBM is -64802.3898
# Historical ES result for MSFT is -65765.0848
# Historical ES result for INTC is -88462.7404

# %% [markdown]
# ## Bid-Ask Spread

# %%
bid_ask = pd.read_csv('bid_ask.csv')

# %%
bid_ask['mid_price'] = (bid_ask['ASKHI'] + bid_ask['BIDLO']) / 2
buyer_seller_initiated = []
for i in range(len(bid_ask)):
    if bid_ask['PRC'][i] > bid_ask['mid_price'][i]:
        buyer_seller_initiated.append(1)
    else:
        buyer_seller_initiated.append(0)
        
bid_ask['buyer_seller_init'] = buyer_seller_initiated

# %%
effective_cost = []
for i in range(len(bid_ask)):
    if bid_ask['buyer_seller_init'][i] == 1:
        effective_cost.append((bid_ask['PRC'][i] - 
                               bid_ask['mid_price'][i]) / 
                               bid_ask['mid_price'][i])
    else:
        effective_cost.append((bid_ask['mid_price'][i] - 
                               bid_ask['PRC'][i])/
                               bid_ask['mid_price'][i])
bid_ask['effective_cost'] = effective_cost

# %%
bid_ask['quoted'] = bid_ask['ASKHI'] - bid_ask['BIDLO']
bid_ask['prop_quoted'] = (bid_ask['ASKHI'] - bid_ask['BIDLO']) /\
                         bid_ask['mid_price']
bid_ask['effective'] = 2 * abs(bid_ask['PRC'] - bid_ask['mid_price'])
bid_ask['prop_effective'] = 2 * abs(bid_ask['PRC'] - 
                                    bid_ask['mid_price']) /\
                                    bid_ask['PRC']

# %%
spread_meas = bid_ask.iloc[:, -5:]
spread_meas.corr()
# Out:
#                 effective_cost    quoted  prop_quoted  effective  \
# effective_cost        1.000000  0.441290     0.727917   0.800894
# quoted                0.441290  1.000000     0.628526   0.717246
# prop_quoted           0.727917  0.628526     1.000000   0.514979
# effective             0.800894  0.717246     0.514979   1.000000
# prop_effective        0.999847  0.442053     0.728687   0.800713
#
#                 prop_effective
# effective_cost        0.999847
# quoted                0.442053
# prop_quoted           0.728687
# effective             0.800713
# prop_effective        1.000000

# %%
spread_meas.describe()
# Out:
#        effective_cost      quoted  prop_quoted   effective  prop_effective
# count      756.000000  756.000000   756.000000  756.000000      756.000000
# mean         0.004247    1.592583     0.015869    0.844314        0.008484
# std          0.003633    0.921321     0.007791    0.768363        0.007257
# min          0.000000    0.320000     0.003780    0.000000        0.000000
# 25%          0.001517    0.979975     0.010530    0.300007        0.003029
# 50%          0.003438    1.400000     0.013943    0.610000        0.006874
# 75%          0.005854    1.962508     0.019133    1.180005        0.011646
# max          0.023283    8.110000     0.055451    6.750000        0.047677

# %%
high_corr = spread_meas.corr().unstack()\
            .sort_values(ascending=False).drop_duplicates()
high_corr[(high_corr > 0.80) & (high_corr != 1)]
# Out:
# prop_effective  effective_cost    0.999847
# effective_cost  effective         0.800894
# prop_effective  effective         0.800713
# dtype: float64

# %%
sorted_spread_measures = bid_ask.iloc[:, -5:-2]

# %%
cross_sec_mean_corr = sorted_spread_measures.mean(axis=1).mean()
std_corr = sorted_spread_measures.std().sum() / 3

# %%
df = pd.DataFrame(index=stocks.columns)
last_prices = []
for i in symbols:
    last_prices.append(stocks[i].iloc[-1])
df['last_prices'] = last_prices

# %%
def ES_parametric(initial_investment, conf_level):
    ES_params = [ ]
    alpha = - norm.ppf(1 - conf_level, stocks_returns_mean, port_std)
    for i,j in zip(stocks.columns,range(len(stocks.columns))):
        VaR_param = (initial_investment * alpha)[j]
        ES_param = (1 / (1 - conf_level)) \
                   * norm.expect(lambda x: VaR_param, lb = conf_level)
        ES_params.append(ES_param)
    return ES_params

# %%
ES_params = ES_parametric(initial_investment, conf_level)
for i in range(len(symbols)):
    print(f'The ES result for {symbols[i]} is {ES_params[i]}')
# Out:
# The ES result for IBM is 143275.54686719523
# The ES result for MSFT is 137864.49655440662
# The ES result for INTC is 144996.68333176174

# %%
k = 1.96

for i, j in zip(range(len(symbols)), symbols):
    print('The liquidity Adjusted ES of {} is {}'
          .format(j, ES_params[i] + (df.loc[j].values[0] / 2) * 
                  (cross_sec_mean_corr + k * std_corr)))
# Out:
# The liquidity Adjusted ES of IBM is 143347.73650672758
# The liquidity Adjusted ES of MSFT is 137992.0499356013
# The liquidity Adjusted ES of INTC is 145025.25409631134

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
spread_meas_scaled = scaler.fit_transform(np.abs(spread_meas))
pca = PCA(n_components=5)
prin_comp = pca.fit_transform(spread_meas_scaled)

# %%
var_expl = np.round(pca.explained_variance_ratio_, decimals=4)
cum_var = np.cumsum(np.round(pca.explained_variance_ratio_,
                             decimals=4))
print('Individually Explained Variances are:\n{}'.format(var_expl)) 
print('=='*30)
print('Cumulative Explained Variances are: {}'.format(cum_var))
# Out:
# Individually Explained Variances are:
# [0.7494 0.1461 0.0983 0.0062 0.    ]
# ============================================================
# Cumulative Explained Variances are: [0.7494 0.8955 0.9938 1.     1.    ]

# %%
plt.plot(pca.explained_variance_ratio_)
plt.xlabel('Number of Components')
plt.ylabel('Variance Explained')
plt.title('Scree Plot')
plt.show()

# %%
pca = PCA(n_components=2)
pca.fit(np.abs(spread_meas_scaled))
prin_comp = pca.transform(np.abs(spread_meas_scaled))
prin_comp = pd.DataFrame(np.abs(prin_comp), columns = ['Component 1',
                                                       'Component 2'])
print(pca.explained_variance_ratio_*100)
# Out:
# [65.65640435 19.29704671]

# %%
def myplot(score, coeff, labels=None):
    xs = score[:, 0]
    ys = score[:, 1]
    n = coeff.shape[0]
    scalex = 1.0 / (xs.max() - xs.min())
    scaley = 1.0 / (ys.max() - ys.min())
    plt.scatter(xs * scalex * 4, ys * scaley * 4, s=5)
    for i in range(n):
        plt.arrow(0, 0, coeff[i, 0], coeff[i, 1], color = 'r',
                  alpha=0.5)
        if labels is None:
            plt.text(coeff[i, 0], coeff[i, 1], "Var"+str(i),
                     color='black')
        else:
            plt.text(coeff[i,0 ], coeff[i, 1], labels[i],
                     color='black')
 
    plt.xlabel("PC{}".format(1))
    plt.ylabel("PC{}".format(2))
    plt.grid()

# %%
spread_measures_scaled_df = pd.DataFrame(spread_meas_scaled,
                                         columns=spread_meas.columns)

# %%
myplot(np.array(spread_measures_scaled_df)[:, 0:2], 
       np.transpose(pca.components_[0:2,:]), 
       list(spread_measures_scaled_df.columns))
plt.show()

# %%
prin_comp1_rescaled = prin_comp.iloc[:,0] * prin_comp.iloc[:,0].std()\
                      + prin_comp.iloc[:, 0].mean()
prin_comp2_rescaled = prin_comp.iloc[:,1] * prin_comp.iloc[:,1].std()\
                      + prin_comp.iloc[:, 1].mean()
prin_comp_rescaled = pd.concat([prin_comp1_rescaled, 
                                prin_comp2_rescaled],
                               axis=1)
prin_comp_rescaled.head()
# Out:
#    Component 1  Component 2
# 0     1.766661     1.256192
# 1     4.835170     1.939466
# 2     3.611486     1.551059
# 3     0.962666     0.601529
# 4     0.831065     0.734612

# %%
mean_pca_liq = prin_comp_rescaled.mean(axis=1).mean()
mean_pca_liq
# Out:
# 1.0647130086973817

# %%
k = 1.96
for i, j in zip(range(len(symbols)), symbols):
    print('The liquidity Adjusted ES of {} is {}'
          .format(j, ES_params[i] + (df.loc[j].values[0] / 2) * 
                  (mean_pca_liq + k * std_corr)))
# Out:
# The liquidity Adjusted ES of IBM is 143380.91513043852
# The liquidity Adjusted ES of MSFT is 138050.67393850716
# The liquidity Adjusted ES of INTC is 145038.3853247295
